# %% [markdown]
# #  *Author @  Jayashree Ghosh*
#    ------------------------------------------------
# ## *Task 3: Exploratory Data Analysis(EDA) of a Sample Superstore*
# ### Dataset used : SampleSuperstore.csv      (*check it up in my github link :*)
# #### *Gradual Rotation Internship Program*
# #### *The Sparks Foundation*
# #### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Importing necessary Libraries

# %%
import pandas as pd               #For working up with the dataframes
import numpy as np                # For numerical calculations
import seaborn as sns             # For plotting graphs and visualization
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('dark_background')

# %% [markdown]
# ### Reading the Dataset

# %%
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ### Exploring the Dataset

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns                       # featues present
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.info()                                # more informative way
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# Descriptive Statistics    -- gives statistics of numerical variables by default
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [raw]
# *Inferences*:
#       1. Sales column has skewness , outliers might be present.
#       2. No missing values present

# %%
# To get the insights of the categorical variables
df.describe(include = 'all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %% [markdown]
# ### Correlation Matrix and HeatMap

# %%
# Correlation matrix 
correlation = df.corr()
correlation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit      Cost  \
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961 -0.014247
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064  0.927710
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253  0.199012
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487  0.061448
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000  0.116757
# Cost           -0.014247  0.927710  0.199012  0.061448  0.116757  1.000000
# Profit%        -0.056863 -0.060972  0.001901 -0.773335  0.215752 -0.160742
#
#               Profit%
# Postal Code -0.056863
# Sales       -0.060972
# Quantity     0.001901
# Discount    -0.773335
# Profit       0.215752
# Cost        -0.160742
# Profit%      1.000000

# %%
# Heat map
plt.figure(figsize=(15,10))
sns.heatmap(correlation,annot = True , cmap = 'cividis')
plt.title("Correlation between the variables", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Correlation between the variables')

# %% [raw]
# **Inference** :
#     1. Sales and profit are moderately correlated
#     2. Sales and cost are highly correlated
#     3. Quantity and profit are moderately correlated
#     4. Discount and profit are negatively correlated

# %% [markdown]
# ## Visualizing the Data

# %% [markdown]
# ### Univariate Analysis

# %%
# Analysing Segment of the supermart
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df['Segment'].value_counts()/len(df['Segment'])*100
# Out:
# Consumer       51.941165
# Corporate      30.218131
# Home Office    17.840704
# Name: Segment, dtype: float64

# %%
plt.figure(figsize=(14,8))
S = (df['Segment'].value_counts()/len(df['Segment'])*100).plot(kind="bar",color="orange",fontsize=15)
plt.show()

# %% [raw]
# ** Inferences: **
#     1. 50% of the people belong to the consumer class
#     2. 20-30% belong to corporate or home office

# %%
# Analysing Ship mode for the Supermart
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
M = ((df['Ship Mode'].value_counts())/len(df['Ship Mode']))*100

# %%
M
# Out:
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: Ship Mode, dtype: float64

# %%
plt.figure(figsize=(14,8))
M.plot(kind = "bar",fontsize = 15)
plt.show()

# %% [raw]
# ** Inferences: **
#     1. Most of the deliveries belong to the standard class(Around 60 %)
#     2. Very less deliveries were performed on the same day
#     3. Only 20 - 30% deliveries belong to the first and second class

# %%
# Analysing the Category of items in the Supermart
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
C = (df['Category'].value_counts())/len(df['Category'])*100

# %%
C
# Out:
# Office Supplies    60.296178
# Furniture          21.222734
# Technology         18.481089
# Name: Category, dtype: float64

# %%
plt.figure(figsize=(14,8))
C.plot(kind = "bar",fontsize = 15,color = "pink")
plt.show()

# %% [raw]
# ** Inference: **
#     1. Most of the categories belong to Office Supplies
#     2. 20-25 % to the furniture and Technology

# %%
# Analysing the sub-category of the items in the Supermart
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
SC = (df['Sub-Category'].value_counts())/len(df['Sub-Category'])*100

# %%
SC
# Out:
# Binders        15.239143
# Paper          13.708225
# Furnishings     9.575745
# Phones          8.895337
# Storage         8.465079
# Art             7.964779
# Accessories     7.754653
# Chairs          6.173704
# Appliances      4.662798
# Labels          3.642185
# Tables          3.191915
# Envelopes       2.541525
# Bookcases       2.281369
# Fasteners       2.171303
# Supplies        1.901141
# Machines        1.150690
# Copiers         0.680408
# Name: Sub-Category, dtype: float64

# %%
SC.nunique()
# Out:
# 17

# %%
plt.figure(figsize=(14,8))
SC.plot(kind = "bar",fontsize = 15,color = "yellow")
plt.show()

# %% [raw]
# ** Inferences: **
#     1. 9-15 % Sub-Categories belongs to Office supplies
#     2. 2-8 % Sub-Categories belongs to Technology and Furniture

# %% [markdown]
# ### Bivariate Analysis

# %%
fig, ax = plt.subplots(figsize=(14,8))
colors = {'Consumer':'orange','Corporate':'blue','Home Office':'purple'}
ax.scatter(df['Sales'],df['Profit'],c= df['Segment'].apply(lambda x : colors[x]))
plt.show()

# %% [raw]
# ** Inference : **
#     1. We can clearly see that there is more profit in the Consumer segment

# %%
# Constructing pivot tables
df.pivot_table(values = 'Sales',index = 'Segment',columns = 'Discount',aggfunc = 'median')
# Out:
# Discount       0.00     0.10     0.15    0.20     0.30      0.32     0.40  \
# Segment
# Consumer     51.900  365.598  307.666  51.540  361.011  328.3992  289.404
# Corporate    58.580  245.646  480.165  52.184  347.361  307.6660  338.679
# Home Office  49.645  191.646  411.332  52.680  362.901  341.9992  212.856
#
# Discount          0.45     0.50    0.60    0.70   0.80
# Segment
# Consumer     353.24025  292.100  23.526  12.051  8.568
# Corporate    562.29250  302.450  21.936  12.060  9.264
# Home Office  427.23725  433.935  22.608  12.957  8.769

# %%
df.pivot_table(values = 'Profit',index = 'Segment',columns = 'Discount',aggfunc = 'median')
# Out:
# Discount        0.00     0.10      0.15    0.20     0.30     0.32      0.40  \
# Segment
# Consumer     16.1240  62.0390   5.12940  6.0433 -26.0562 -30.0980 -47.21360
# Corporate    16.2688  46.7908  26.27735  6.7054 -28.2240 -59.0606 -87.27495
# Home Office  15.4546  37.2300  16.79860  7.2576 -18.2040 -57.3234 -49.71900
#
# Discount          0.45      0.50     0.60    0.70     0.80
# Segment
# Consumer    -135.68145 -175.2600 -14.1323 -8.7276 -13.7175
# Corporate   -255.58750 -120.5130 -10.4196 -8.9796 -16.3800
# Home Office -175.14690 -237.8425 -14.2290 -9.7608 -14.0328

# %% [raw]
# ** Inferences: **
#     1. For Discount more than 30% the Superstore was running on loss.
#     2. For items having discount b/w 0 to 20% , yielded moderate profits to the superstore

# %%
# Plotting Histogram for profit
temp_df = df.loc[(df['Segment']=='Consumer')&(df['Discount']==0.1)]
plt.figure(figsize=(14,8))
temp_df['Profit'].plot.hist(bins = 50,edgecolor='white',color='red',fontsize=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
temp_df = df.loc[(df['Segment']=='Consumer')&(df['Discount']==0.2)]
plt.figure(figsize=(14,8))
temp_df['Profit'].plot.hist(bins = 50,edgecolor='white',color='red',fontsize=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
temp_df = df.loc[(df['Segment']=='Consumer')&(df['Discount']==0.8)]
plt.figure(figsize=(14,8))
temp_df['Profit'].plot.hist(bins = 50,edgecolor='white',color='red',fontsize=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [raw]
# ** Inference: *
#     1. For all Segments when superstore is offering discount less than 40% ,its gaining profit
#     2. Whereas, for Discounts > 50% , the Superstore faces loss as depicted by the above plots.

# %%
# Similarly plotting the histograms for category
temp_df = df.loc[(df['Category']=='Furniture')&(df['Discount']==0.2)]
plt.figure(figsize=(14,8))
temp_df['Profit'].plot.hist(bins = 50,edgecolor='white',color='red',fontsize=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
temp_df = df.loc[(df['Category']=='Technology')&(df['Discount']<= 0.3)]
plt.figure(figsize=(14,8))
temp_df['Profit'].plot.hist(bins = 50,edgecolor='white',color='red',fontsize=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
temp_df = df.loc[(df['Category']=='Technology')&(df['Discount'] >= 0.3)]
plt.figure(figsize=(14,8))
temp_df['Profit'].plot.hist(bins = 50,edgecolor='white',color='red',fontsize=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
temp_df = df.loc[(df['Category']=='Office Supplies')&(df['Discount']<= 0.3)]
plt.figure(figsize=(14,8))
temp_df['Profit'].plot.hist(bins = 50,edgecolor='white',color='red',fontsize=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
temp_df = df.loc[(df['Category']=='Office Supplies')&(df['Discount'] >= 0.3)]
plt.figure(figsize=(14,8))
temp_df['Profit'].plot.hist(bins = 50,edgecolor='white',color='red',fontsize=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
** Inference: **
     1. From the above graphs we conclude that,for all categories i.e Office supplies, Technology and furniture 
        the Supermart is running at profit when discount is <=30%
        and on loss when Discount >= 30%

# %%
temp = df.groupby(['Segment','Discount']).Profit.median()
plt.figure(figsize=(14,8))
temp.plot(kind = 'bar',stacked = True)
# Out:
# <AxesSubplot:xlabel='Segment,Discount'>
